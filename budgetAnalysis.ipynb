# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('./addedroi.csv')

# %%
data
# Out:
#       Unnamed: 0.1  Unnamed: 0                        name studio  \
# 0                0           0                 Toy Story 3     BV
# 1                1           1                   Inception     WB
# 2                2           2         Shrek Forever After   P/DW
# 3                3           3  The Twilight Saga: Eclipse   Sum.
# 4                4           4                  Iron Man 2   Par.
# ...            ...         ...                         ...    ...
# 1947          1947        2092                       Mandy    RLJ
# 1948          1948        2093                       Mandy    RLJ
# 1949          1949        2094                       Mandy    RLJ
# 1950          1950        2095                Lean on Pete    A24
# 1951          1951        2096                Lean on Pete    A24
#
#       runtime_minutes                      genres original_language  \
# 0               103.0  Adventure,Animation,Comedy                en
# ...

# %%
data['production_budget']
# Out:
# 0       $200,000,000
# 1       $160,000,000
# 2       $165,000,000
# 3        $68,000,000
# 4       $170,000,000
#             ...
# 1947      $6,000,000
# 1948      $6,000,000
# 1949      $6,000,000
# 1950      $8,000,000
# 1951      $8,000,000
# Name: production_budget, Length: 1952, dtype: object

# %%
budget = [float(value.replace("$", "").replace(",", "")) for value in data['production_budget']]

# %%
# Out:
# [200000000.0,
#  160000000.0,
#  165000000.0,
#  68000000.0,
#  170000000.0,
#  260000000.0,
#  69000000.0,
#  165000000.0,
#  155000000.0,
#  40000000.0,
#  8000000.0,
#  13000000.0,
#  130000000.0,
#  210000000.0,
#  99000000.0,
#  210000000.0,
#  99000000.0,
#  210000000.0,
#  99000000.0,
#  210000000.0,
#  99000000.0,
#  210000000.0,
#  99000000.0,
#  210000000.0,
#  99000000.0,
#  210000000.0,
#  99000000.0,
#  210000000.0,
#  99000000.0,
#  210000000.0,
#  99000000.0,
#  210000000.0,
#  99000000.0,
#  210000000.0,
#  99000000.0,
#  210000000.0,
#  99000000.0,
#  150000000.0,
#  100000000.0,
#  57500000.0,
#  80000000.0,
#  130000000.0,
#  130000000.0,
#  95000000.0,
#  100000000.0,
#  82000000.0,
#  75000000.0,
#  35000000.0,
#  112000000.0,
#  40000000.0,
#  52000000.0,
#  160000000.0,
#  65000000.0,
#  60000000.0,
#  80000000.0,
#  60000000.0,
#  60000000.0,
#  60000000.0,
#  60000000.0,
#  3000000.0,
#  110000000.0,
#  100000000.0,
#  95000000.0,
#  95000000.0,
# ...

# %%
vals = data['roi'].to_list()

# %%
# Plotting
plt.figure(figsize=(12, 6))
plt.scatter(vals, budget)
plt.title('Average ROI by Budget')
plt.xlabel('roi')
plt.ylabel('Average ROI')
plt.xticks(rotation=45)
plt.grid(axis='x')
plt.show()
